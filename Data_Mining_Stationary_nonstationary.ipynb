# %% [markdown]
# <a href="https://colab.research.google.com/github/ucchol/docker/blob/main/Data_Mining_Stationary_nonstationary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('samples.csv',\
                     parse_dates=True)

# %%
df
# Out:
#     Unnamed: 0   a   b      c   d
# 0     1/1/1950  36  27      0  67
# 1     2/1/1950  58  22      3  31
# 2     3/1/1950  61  17      5  67
# 3     4/1/1950  37  15      8  47
# 4     5/1/1950  66  13      8  62
# ..         ...  ..  ..    ...  ..
# 115   8/1/1959  49  73   9338  58
# 116   9/1/1959  41  77   9502  38
# 117  10/1/1959  64  70   9667  42
# 118  11/1/1959  37  87   9833  62
# 119  12/1/1959  38  73  10000  50
#
# [120 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  120 non-null    object
#  1   a           120 non-null    int64
#  2   b           120 non-null    int64
#  3   c           120 non-null    int64
#  4   d           120 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 4.8+ KB

# %%
df['c'].plot()#non-stationary
# Out:
# <Axes: >

# %%
#stationary --> no trend
df['d'].plot()
# Out:
# <Axes: >

# %%
df['a'].plot()
# Out:
# <Axes: >

# %% [markdown]
# Uni-variant time series: EWMA, you only have only time-series going on. So, only one variable. Time series might come with multiple variable, which are known as multi-variant time series, it isn't covered in our topics.

# %% [markdown]
# Information can be latent, seasonality can be hidden in the data.

# %%
df['b'].plot()
# Out:
# <Axes: >

# %%
(df['b']-df['b'].shift(-1)).plot()
# Out:
# <Axes: >

# %% [markdown]
# #what is first-order and 2nd order differencing?
# 2nd order differencing might have qudratic trend.

# %%
from statsmodels.tsa.statespace.tools import diff

# %%
#1st Order differencing
diff(df['b'], k_diff=1).plot()
# Out:
# <Axes: >

# %%
#2nd Order differencing
diff(df['b'], k_diff=2).plot()
# Out:
# <Axes: >

# %%
#10th Order differencing
diff(df['b'], k_diff=10).plot()
# Out:
# <Axes: >

# %%
#20th Order differencing
diff(df['b'], k_diff=20).plot()
# Out:
# <Axes: >
