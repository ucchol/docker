# %% [markdown]
# <a href="https://colab.research.google.com/github/ucchol/docker/blob/main/Data_Mining_ETS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv("airline_passengers.csv", index_col=0, parse_dates=True)
df
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121
# ...                             ...
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432
#
# [144 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 1 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Thousands of Passengers  144 non-null    int64
# dtypes: int64(1)
# memory usage: 2.2 KB

# %%
df.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result_mul = seasonal_decompose(\
    df['Thousands of Passengers'], model="mul")
result_mul.plot()

# %%
trend = result_mul.trend
seasonal=result_mul.seasonal
errorPart = result_mul.resid
